# %%
#writing your first function
def printInfo():
    print("Name: Brandon Partain")
    print("Age: 34")
printInfo()
printInfo()
# Out:
# Name: Brandon Partain
# Age: 34
# Name: Brandon Partain
# Age: 34

# %%
# performing a calculation in a function
def calc():
    x,y=5,10
    print(x+y)
calc()
# Out:
# 15

# %%
# passing a single parameter inro a function
def printName(full_name):
    print("Your name is: {}".format(full_name))
printName("Brandon Partain")
printName("Brandon")
# Out:
# Your name is: Brandon Partain
# Your name is: Brandon

# %%
def addnums(num1,num2):
    result= num1+num2
    print("{}+{}={}".format(num1,num2,result))
addnums(5,8)
addNums(3.5,5.5)
# Out:
# 5+8=13
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 5
#       3     print("{}+{}={}".format(num1,num2,result))
#       4 addnums(5,8)
# ----> 5 addNums(3.5,5.5)
#
# NameError: name 'addNums' is not defined

# %%
numbers1= [2,4,5,10]
numbers2= [1,3,6]
def squares(nums):
    for num in nums:
        print(num**2)
squares(numbers1)
squares(numbers2)
# Out:
# 4
# 16
# 25
# 100
# 1
# 9
# 36

# %%
def calcArea(r,pi=3.14):
    area=pi*(r**2)
    print("Area: {}".format(area))
calcArea(2)
# Out:
# Area: 12.56

# %%
def addNums(num1,num2):
    print(num2)
    print(num1)
addNums(5,num2=2.5)
# Out:
# 2.5
# 5

# %%
def outputData(name,*args):
    print(type(args))
    for arg in args:
        print(arg)
outputData("John Smith",5,True,"Jess")
# Out:
# <class 'tuple'>
# 5
# True
# Jess

# %%
def outputData(**kwargs):
    print(type(kwargs))
    print(kwargs["name"])
    print(kwargs["num"])
outputData(name="John Smith",num=5,b=True)
# Out:
# <class 'dict'>
# John Smith
# 5

# %%
def addNums(num1,num2):
    return num1+num2
num=addNums(5.5,4.5)
print(num)
print(addNums(10,10))
# Out:
# 10.0
# 20

# %%
def searchList(alist,el):
    return True if el in alist else False
    result= searchList(["one",2,"three"],2)
print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       2     return True if el in alist else False
#       3     result= searchList(["one",2,"three"],2)
# ----> 4 print(result)
#
# NameError: name 'result' is not defined

# %%
def searchList(alist,el):
    return True if el in alist else False

# Fixed indentation - this line should be at the top level, not inside the function
result = searchList(["one",2,"three"],2)
print(result)
# Out:
# True

# %%
number=5
def scopeTest():
    number +=1
scopeTest()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[15], line 4
#       2 def scopeTest():
#       3     number +=1
# ----> 4 scopeTest()
#
# Cell In[15], line 3, in scopeTest()
#       2 def scopeTest():
# ----> 3     number +=1
#
# UnboundLocalError: cannot access local variable 'number' where it is not associated with a value

# %%
number = 5

def scopeTest(num):
    return num + 1  # Return the incremented value instead of modifying global

result = scopeTest(number)
print(result)  # This will print 6
# Out:
# 6

# %%
def scopeTest():
    word= "function"
    return word
value=scopeTest()
print(value)
# Out:
# function
