# %% [raw]
# print('{} is my favorite sport'.format(element))
# element = 'FootBall'

# %%
# accepting and outputting user input
print(input("What is your name?"))
# Out:
# What is your name? Brandon
# Brandon

# %%
# saving what the user inputs
ans= input("What is your name?")
print("Hello {}!".format(ans))
# Out:
# What is your name? Brandon
# Hello Brandon!

# %%
# how to check the data type of a variable
num = 5
print(type(num))
# Out:
# <class 'int'>

# %%
# converting a variable from one data type to another
num="9"
num= int(num) # re-declaring num to store an integer
print(type(num)) #checking type to make sure conversion worked
# Out:
# <class 'int'>

# %%
# working with user input to perform calculations
ans =input("Type a number to add:")
print(type(ans)) #default type is string, must convert
result = 100 + int(ans)
print("100 + {} = {}".format(ans,result))
# Out:
# Type a number to add: 9
# <class 'str'>
# 100 + 9 = 109

# %%
# using an if statement to only run code if the condition is met
x, y=5,10
if x<y:
    print("x is less trhan y")
# Out:
# x is less trhan y

# %%
# checking user input
ans =int(input("What vis 5+5?"))
if ans ==10:
    print("You got it right!")
# Out:
# What vis 5+5? 10
# You got it right!

# %%
# using the keyword "and" in an "if statement"
x,y, z= 5,10,5
if x < y and x==z:
    print("Both statements were true")
# Out:
# Both statements were true

# %%
# using the keyword 'or' in an 'if statement'
x,y,z=5,10,5
if x<y or x !=z:
    print("One or both statements were true")
# Out:
# One or both statements were true

# %%
# using the keyboard "not" within an "if statement"
flag=false # same as saying if not true
    print("Flag is false")
# Out:
#   Cell In[11], line 3
#     print("Flag is false")
#     ^
# IndentationError: unexpected indent

# %%
# using the keyword "not" within an "if statement"
flag = False  # Changed 'false' to 'False' (Python boolean values are capitalized)
if not flag:  # Added the missing 'if' statement
    print("Flag is false")  # This indentation is now correct because it's inside the if block
# Out:
# Flag is false

# %%
# using the keyword 'in" within an 'if' statement'
word = "Baseball"
if "b" in word:
    print("{} conains the character b".format(word))
# Out:
# Baseball conains the character b

# %%
# using the keyword "not in" within an 'if statement'
word = "Baseball"
if "x" not in word:
    print("{} does not contain the charactewr x".format(word))
# Out:
# Baseball does not contain the charactewr x

# %%
# using the elif conditional statement
x, y =5,10
if x>y:
    print("x is greater")
elif x<y:
    print("x is less")
# Out:
# x is less

# %%
# checking more than one elif conditional statements 
x,y=5,10
if x>y:
    print("x is greater")
    elif(x+10)<y: # checking if 15 is less than 10
    print("x is less") 
elif(x+5)==y: #checking if 10 is equal to 10
print("equal")
# Out:
#   Cell In[16], line 5
#     elif(x+10)<y: # checking if 15 is less than 10
#     ^
# SyntaxError: invalid syntax

# %%
# checking more than one elif conditional statements 
x,y=5,10
if x>y:
    print("x is greater")
elif(x+10)<y: # checking if 15 is less than 10 - Fixed indentation to align with 'if'
    print("x is less") 
elif(x+5)==y: # checking if 10 is equal to 10 - Fixed indentation to align with 'if'
    print("equal")
# Out:
# equal

# %%
#writing multiple conditionals within each other-multiple block levels
x,y,z=5,10,5
if x > y:
    print("greater")
elif x<=y:
    if x==z:
        print("x is equal to z") #resulting output
    elif x !=z:
        print("x is not equal to z") #won't get hit
# Out:
# x is equal to z

# %%
# testing output of two if statements in a row that are both true
x,y,z=5,10,5
if x<y:
    print("x is less")
if x ==z:
    print("x is equal")
# Out:
# x is less
# x is equal

# %%
# using an else statement
name= "Brandon"
if name == "Brian":
    print("Hello Brian!")
else:
    print("Hello{}!".format(name))
# Out:
# HelloBrandon!
