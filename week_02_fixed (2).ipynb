# %%
# comments & Basic Data Types

# %%
# this is a comment

# %%
print("Hello") # This is also a comment
# Out:
# Hello

# %%
"""
This is a multi-line comment
"""
Print("Yikes") #this is also a commemnt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 """
#       2 This is a multi-line comment
#       3 """
# ----> 4 Print("Yikes")
#
# NameError: name 'Print' is not defined

# %%
"""
This is a multi-line comment
"""
print("Yikes!")
# Out:
# Yikes!

# %%
# the following are all integers
print(2)
print(12)
# Out:
# 2
# 12

# %%
# the following are all floats
print(10.953)
print(8.0)  #even this number is a float
# Out:
# 10.953
# 8.0

# %%
# the following are booleans
print(True)
print(False)
# Out:
# True
# False

# %%
# the following are strings
print("")
print("There's a hole in my pants!")
print('True')
# Out:
# There's a hole in my pants!
# True

# %% [markdown]
# # the following are strings
# print("")
# print("My name is Brandon and my name strike fear into the hearts of man")
# print('True')

# %%
first_name = "Brandon"

# %%
num1= 5  #storing an integer into a variable
num2= 8.4  #storing a float into a variable
print(num1,num2) # you can print multiple items using commas
# Out:
# 5 8.4

# %%
# storing a boolean into a variable
switch = True
print( switch)
# Out:
# True

# %%
# storing strings into a variable
name = "John Smith"
fav_number = '13'
print(name, fav_number)  # will print 13 next to the name
# Out:
# John Smith 13

# %% [markdown]
# # using two variables to create another variable
# result = num1 +num2
# print(result)

# %%
result = num1 + num2
print(result)
# Out:
# 13.4

# %%
result +=1 #same as saying result = result +1
print(result)
result *= num1 # same as saying result = result = result * num1
print(result)
# Out:
# 14.4
# 72.0

# %%
# using the addition operator without variables
first_name = "Brandon"
Last_name = "Partain"
full_name = first_name + "" + last_name
print(full_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 4
#       2 first_name = "Brandon"
#       3 Last_name = "Partain"
# ----> 4 full_name = first_name + "" + last_name
#       5 print(full_name)
#
# NameError: name 'last_name' is not defined

# %%
# using the addition operator without variables
first_name = "Brandon"
last_name = "Partain"  # Changed from 'Last_name' to 'last_name' for consistency
full_name = first_name + " " + last_name  # Also added a space between names
print(full_name)
# Out:
# Brandon Partain

# %%
# using the addition operator without variables
first_name = "Brandon"
Last_name = "Partain"
full_name = first_name + " " + Last_name  # Added missing '+' operator and space for proper formatting
print(full_name)
# Out:
# Brandon Partain

# %%
# injecting variables using the format method
name = "Brandon"
print("Hello {}".format(name))
print(" Hello {}, you are {} years old!".format(name,34))
# Out:
# Hello Brandon
#  Hello Brandon, you are 34 years old!

# %%
# using the new f strings
name = "Brandon"
print(f"Hello{name}")
# Out:
# HelloBrandon

# %%
# one major difference between versions 2 &3
name= 'Brandon'
print("Hello, %s'%name)
# Out:
#   Cell In[23], line 3
#     print("Hello,%s'%name)
#           ^
# SyntaxError: unterminated string literal (detected at line 3)

# %%
# one major difference between versions 2 &3
name = 'Brandon'
print("Hello, %s" % name)  # Fixed: Added missing closing double quote and corrected string formatting
# Out:
# Hello, Brandon

# %%
name = 'Brandon'
print("Hello, %s" % name)
# Out:
# Hello, Brandon

# %%
# python 2 multiple variable formatting
first_name = "Brandon"
last_name = "Partain"
print( "Hello,%s %s" % (first_name, last_name))
 # surround the variables in parenthesis
# Out:
# Hello,Brandon Partain

# %%
word = "Hello"
print(word[0]) #will output 'H'
print(word[1])  #will output 'e'
print(word[-1]) #will output 'o"
# Out:
# H
# e
# o

# %%
print(word[0:2]) #will output 'He'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(word[0:2])
#
# NameError: name 'word' is not defined

# %%
word = "Hello"
print(word[0:2]) #will output 'He'
# Out:
# He

# %%
word="Hello"
print( word[0:5:2]) #will output "Hlo"
# Out:
# Hlo

# %%
#using the title method to capitalize a string
name = "Brandon Partain"
print(name.title())
# Out:
# Brandon Partain

# %%
name = "Brandon Partain"
print(name.lower())
# Out:
# brandon partain

# %%
name = "Brandon Partain"
print(name.upper())
# Out:
# BRANDON PARTAIN

# %%
# replacing an exclamation point with a period
words = "Hello there!"
print(words.replace("!","."))
# Out:
# Hello there.

# %%
words= "Welcome!"
print(words.replace("!","."))
# Out:
# Welcome.

# %%
# finding the starting index of our searched term
s= "Look over that way"
print(s.find("over"))
# Out:
# 5

# %%
# removing white space with strip
name= "  Brandon "
print(name.strip())
# Out:
# Brandon

# %%
# converting a string into a list of words
s= "These words are separated by spaces"
print(s.split(""))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 3
#       1 # converting a string into a list of words
#       2 s= "These words are separated by spaces"
# ----> 3 print(s.split(""))
#
# ValueError: empty separator

# %%
# converting a string into a list of words
s = "These words are separated by spaces"
# Use split() with no arguments to split on whitespace (recommended)
print(s.split())
# Alternative: Use split(" ") to explicitly split on spaces
# print(s.split(" "))
# Out:
# ['These', 'words', 'are', 'separated', 'by', 'spaces']

# %%
# create a product and price for three items
p1_name, p1_price = "Books",49.95
p2_name, p2_price = "Computer", 579.99
p3_name, p3_price = "Monitor" . 124.89
# create a company name and information
company_name= "coding temple,inc,"
company_address = "283 Franklin St,"
Company_city = "Boston,MA"
# declare ending message
message = "Thanks for shopping with us today!"
# Out:
#   Cell In[13], line 4
#     p3_name, p3_price = "Monitor" . 124.89
#                                     ^
# SyntaxError: invalid syntax

# %%
# create a product and price for three items
p1_name, p1_price = "Books",49.95
p2_name, p2_price = "Computer", 579.99
p3_name, p3_price = "Monitor", 124.89  # Changed period (.) to comma (,)
# create a company name and information
company_name= "coding temple,inc,"
company_address = "283 Franklin St,"
Company_city = "Boston,MA"
# declare ending message
message = "Thanks for shopping with us today!"

# %%
# crrate a top border
print("*" * 50)
# Out:
# **************************************************

# %%
# Print company information first, using format
print("\t\{ }".format(company_name.title())
print("\t\t{ }".format(company_address))
print( "\t\{ }".format(company_city))
# Out:
#   Cell In[17], line 2
#     print("\t\{ }".format(company_name.title())
#          ^
# SyntaxError: '(' was never closed

# %%
# Print company information first, using format
print("\t{}".format(company_name.title()))  # Added missing closing parenthesis and removed incorrect backslashes
print("\t\t{}".format(company_address))     # Removed incorrect backslashes from format placeholders
print("\t{}".format(company_city))          # Removed incorrect backslashes from format placeholders
# Out:
# 	Coding Temple,Inc,
# 		283 Franklin St,
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 4
#       2 print("\t{}".format(company_name.title()))  # Added missing closing parenthesis and removed incorrect backslashes
#       3 print("\t\t{}".format(company_address))     # Removed incorrect backslashes from format placeholders
# ----> 4 print("\t{}".format(company_city))
#
# NameError: name 'company_city' is not defined

# %%
# Define the company variables first
company_name = "Your Company Name"
company_address = "123 Main Street"
company_city = "Your City, State ZIP"

# Print company information using format
print("\t{}".format(company_name.title()))  # Added missing closing parenthesis and removed incorrect backslashes
print("\t\t{}".format(company_address))     # Removed incorrect backslashes from format placeholders
print("\t{}".format(company_city))          # Removed incorrect backslashes from format placeholders
# Out:
# 	Your Company Name
# 		123 Main Street
# 	Your City, State ZIP

# %%
# print a line between sections
print( "=") *50
# Out:
# =
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 # print a line between sections
# ----> 2 print( "=") *50
#
# TypeError: unsupported operand type(s) for *: 'NoneType' and 'int'

# %%
# print a line between sections
print("=" * 50)

# %%
# print out header for section of items
print("\tProduct Name\tProductPrice")
# Out:
# 	Product Name	ProductPrice

# %%
# creat a print statement for each product
print("\t{}\t\t${}".format(p1_name.title(),p1_price))
print("\t{}\t\t${}".format(p2_name.title(),p2_price))
print("\t{}\t\t${}".format(p3_name.title(),p3_price))
# Out:
# 	Books		$49.95
# 	Computer		$579.99
# 	Monitor		$124.89

# %%
# print a line between sections
print("=" * 50)

# %%
# print out header for section of total
print("\t\t\tTotal")
# Out:
# 			Total

# %%
# calculate totasl price and print out
total = p1_price + p2_price+p3_price
print("\t\t\t${}".format(total))
# Out:
# 			$754.83

# %%
# print a line between sections
print("=" *50)

# %%
# output thank you message
print("\n\t{}\n".format(message))
# Out:
# 	Thanks for shopping with us today!

# %%
# create a bottom boarder
print("*"*50)
# Out:
# **************************************************
